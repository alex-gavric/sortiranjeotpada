# %% [markdown]
# # Masinsko ucenje
# #### Aleksandar Gavric
#
# ## Klasifikacija slika otpada na klase karton, staklo, metal, papir, plastika ili djubre
#
# Zagađenje recikliranjem nastaje kada se otpad nepravilno odlaže - poput recikliranja kutije za picu sa uljem na njoj (kompost). Ili kada se otpad pravilno odlaže, ali pogrešno priprema - poput recikliranja neispranih tegli za džem.
# Kontaminacija je veliki problem u reciklažnoj industriji koji se može ublažiti automatskim optičkim sortiranjem otpada.
#
# Obučavamo konvolucionu neuronsku mrežu da klasifikuje sliku kao karton, staklo, metal, papir, plastiku ili smeće.

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %config InlineBackend.figure_format = 'retina'

# %%
from pathlib import Path
from glob2 import glob
from sklearn.metrics import confusion_matrix

import pandas as pd
import numpy as np
import os
import zipfile as zf
import shutil
import re
import seaborn as sns
import random

# %% [markdown]
# ## 1. Ekstraktovanje podataka

# %% [markdown]
# Ekstraktovanje podataka koji su u "dataset-resized.zip".

# %%
files = zf.ZipFile("dataset-resized.zip",'r')
files.extractall()
files.close()

# %% [markdown]
# imamo 6 potfoldera:

# %%
os.listdir(os.path.join(os.getcwd(),"dataset-resized"))
# Out:
# ['.DS_Store', 'cardboard', 'glass', 'metal', 'paper', 'plastic', 'trash']

# %% [markdown]
# ## 2. Reorganizacija slika u foldere test, valid i train
#
# Pravimo foldere train, validation, i test sa 50-25-25 % splitom originalnog seta.

# %%
def split_indices(folder,seed1,seed2):    
    n = len(os.listdir(folder))
    full_set = list(range(1,n+1))

    random.seed(seed1)
    train = random.sample(list(range(1,n+1)),int(.5*n))

    remain = list(set(full_set)-set(train))

    random.seed(seed2)
    valid = random.sample(remain,int(.5*len(remain)))
    test = list(set(remain)-set(valid))
    
    return(train,valid,test)

def get_names(waste_type,indices):
    file_names = [waste_type+str(i)+".jpg" for i in indices]
    return(file_names)    

def move_files(source_files,destination_folder):
    for file in source_files:
        shutil.move(file,destination_folder)

# %% [markdown]
# Pravimo direktorijume po konvenciji takmicenja ImageNet. Izgledace ovako:
#
# /data <br>
# &nbsp;&nbsp;&nbsp;&nbsp; /train <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /cardboard <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /glass <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /metal <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /paper <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /plastic <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /trash <br>
# &nbsp;&nbsp;&nbsp;&nbsp; /valid <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /cardboard <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /glass <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /metal <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /paper <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /plastic <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;    /trash <br>
# &nbsp;&nbsp;&nbsp;&nbsp;/test <br>
#
# Nazivi slika ce biti klasa i redni broj slike (npr. cardboard1.jpg)

# %%
subsets = ['train','valid']
waste_types = ['cardboard','glass','metal','paper','plastic','trash']

# %%
for subset in subsets:
    for waste_type in waste_types:
        folder = os.path.join('data',subset,waste_type)
        if not os.path.exists(folder):
            os.makedirs(folder)
            
if not os.path.exists(os.path.join('data','test')):
    os.makedirs(os.path.join('data','test'))
            
for waste_type in waste_types:
    source_folder = os.path.join('dataset-resized',waste_type)
    train_ind, valid_ind, test_ind = split_indices(source_folder,1,1)
    
    train_names = get_names(waste_type,train_ind)
    train_source_files = [os.path.join(source_folder,name) for name in train_names]
    train_dest = "data/train/"+waste_type
    move_files(train_source_files,train_dest)
    
    valid_names = get_names(waste_type,valid_ind)
    valid_source_files = [os.path.join(source_folder,name) for name in valid_names]
    valid_dest = "data/valid/"+waste_type
    move_files(valid_source_files,valid_dest)
    
    test_names = get_names(waste_type,test_ind)
    test_source_files = [os.path.join(source_folder,name) for name in test_names]
    
    move_files(test_source_files,"data/test")

# %% [markdown]
# Stavljamo random seed na 1 zbog reproduktivnosti

# %%
path = Path(os.getcwd())/"data"
path
# Out:
# WindowsPath('C:/HOME/MU3/data')

# %%
img_width, img_height = 32, 32 #224, 224
batch_size = 32
num_classes = 6

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
project_dir = str(path)
trainset_dir = project_dir+'\\train'
testset_dir = project_dir+'\\valid'

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        rotation_range=30,
        width_shift_range=0.2,
        height_shift_range=0.2)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    trainset_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size)

test_generator = test_datagen.flow_from_directory(
    testset_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size)
# Out:
# Found 1262 images belonging to 6 classes.
# Found 630 images belonging to 6 classes.

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Activation, BatchNormalization
from keras import backend as K
from keras import optimizers, regularizers, Model
from keras.applications import densenet

# %%
def generate_transfer_model(input_shape, num_classes):
    base_model = densenet.DenseNet121(
        include_top=False,
        weights='imagenet',
        input_tensor=None,
        input_shape=input_shape,
        pooling='max')

    x = base_model.output
    #x = Dense(256, activation="relu")(x)
    x = Dense(16, activation="elu", kernel_regularizer=regularizers.l2(0.1))(x)
    x = Dropout(0.6)(x)
    x = BatchNormalization()(x)
    predictions = Dense(num_classes, activation="softmax")(x)
    model = Model(inputs=base_model.input, outputs=predictions)

    #optimizer = optimizers.Adam(lr=0.0001)
    optimizer = optimizers.SGD(lr=0.001, momentum=0.9, nesterov=True)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
from keras import backend as K

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

print("generisanje modela")
model = generate_transfer_model(input_shape, num_classes)
# Out:
# generisanje modela
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
import matplotlib.pyplot as plt
import numpy as np

n_epochs = 50
training_period = 3
load_weights_file = project_dir+'weights_save_{}.h5'.format(training_period)
save_weights_file = project_dir+'weights_save_{}.h5'.format(training_period+1)

def load_weights():
    print("Ucitane tezine")
    model.load_weights(load_weights_file)

def fit(n_epochs):
    print("Pocelo fitovanje")
    history = model.fit_generator(
        train_generator,
        steps_per_epoch=len(train_generator),
        epochs=n_epochs,
        validation_data=test_generator,
        validation_steps=len(test_generator))
    
    print("Cuvanje tezina")
    model.save_weights(save_weights_file)
    
    print(history.history.keys())
    plt.plot(history.history['acc'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()


def print_layers():
    for layer in model.layers:
        print(layer.name)
        print("trainable: "+str(layer.trainable))
        print("input_shape: " + str(layer.input_shape))
        print("output_shape: " + str(layer.output_shape))
        print("_____________")

    

load_weights()
#fit(n_epochs)
# Out:
# Pocelo fitovanje
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/50
# 40/40 [==============================] - 85s 2s/step - loss: 4.9510 - acc: 0.2653 - val_loss: 4.2657 - val_acc: 0.4381
# Epoch 2/50
# 40/40 [==============================] - 36s 895ms/step - loss: 4.1647 - acc: 0.3830 - val_loss: 3.6711 - val_acc: 0.5254
# Epoch 3/50
# 40/40 [==============================] - 35s 876ms/step - loss: 3.5747 - acc: 0.4855 - val_loss: 3.1695 - val_acc: 0.5889
# Epoch 4/50
# 40/40 [==============================] - 35s 887ms/step - loss: 3.1568 - acc: 0.5311 - val_loss: 2.8008 - val_acc: 0.6365
# Epoch 5/50
# 40/40 [==============================] - 36s 890ms/step - loss: 2.8496 - acc: 0.5662 - val_loss: 2.5050 - val_acc: 0.6794
# Epoch 6/50
# 40/40 [==============================] - 37s 918ms/step - loss: 2.5315 - acc: 0.5981 - val_loss: 2.2621 - val_acc: 0.6635
# Epoch 7/50
# 40/40 [==============================] - 35s 882ms/step - loss: 2.2299 - acc: 0.6299 - val_loss: 2.0430 - val_acc: 0.6794
# Epoch 8/50
# 40/40 [==============================] - 36s 888ms/step - loss: 2.0716 - acc: 0.6393 - val_loss: 1.8518 - val_acc: 0.6889
# Epoch 9/50
# 40/40 [==============================] - 38s 945ms/step - loss: 1.8959 - acc: 0.6528 - val_loss: 1.6806 - val_acc: 0.7095
# Epoch 10/50
# 40/40 [==============================] - 36s 902ms/step - loss: 1.7369 - acc: 0.6405 - val_loss: 1.5473 - val_acc: 0.7063
# Epoch 11/50
# 40/40 [==============================] - 36s 909ms/step - loss: 1.5495 - acc: 0.7005 - val_loss: 1.4771 - val_acc: 0.6952
# Epoch 12/50
# 40/40 [==============================] - 36s 910ms/step - loss: 1.4363 - acc: 0.6940 - val_loss: 1.4045 - val_acc: 0.7159
# Epoch 13/50
# 40/40 [==============================] - 36s 903ms/step - loss: 1.3706 - acc: 0.6930 - val_loss: 1.2691 - val_acc: 0.7365
# Epoch 14/50
# 40/40 [==============================] - 37s 922ms/step - loss: 1.2896 - acc: 0.6995 - val_loss: 1.1962 - val_acc: 0.7254
# Epoch 15/50
# 40/40 [==============================] - 38s 938ms/step - loss: 1.1904 - acc: 0.7194 - val_loss: 1.1948 - val_acc: 0.7079
# Epoch 16/50
# 40/40 [==============================] - 38s 960ms/step - loss: 1.1855 - acc: 0.6913 - val_loss: 1.1321 - val_acc: 0.7222
# Epoch 17/50
# 40/40 [==============================] - 38s 960ms/step - loss: 1.1004 - acc: 0.7218 - val_loss: 1.0512 - val_acc: 0.7222
# Epoch 18/50
# 40/40 [==============================] - 36s 898ms/step - loss: 1.0309 - acc: 0.7427 - val_loss: 1.0275 - val_acc: 0.7302
# Epoch 19/50
# 40/40 [==============================] - 37s 936ms/step - loss: 1.0132 - acc: 0.7325 - val_loss: 0.9973 - val_acc: 0.7206
# Epoch 20/50
# 40/40 [==============================] - 37s 932ms/step - loss: 0.9777 - acc: 0.7427 - val_loss: 0.9657 - val_acc: 0.7222
# Epoch 21/50
# 40/40 [==============================] - 37s 936ms/step - loss: 0.9290 - acc: 0.7513 - val_loss: 0.9122 - val_acc: 0.7476
# Epoch 22/50
# 40/40 [==============================] - 39s 973ms/step - loss: 0.8755 - acc: 0.7708 - val_loss: 0.9270 - val_acc: 0.7143
# Epoch 23/50
# 40/40 [==============================] - 37s 925ms/step - loss: 0.8721 - acc: 0.7538 - val_loss: 0.9072 - val_acc: 0.7317
# Epoch 24/50
# 40/40 [==============================] - 42s 1s/step - loss: 0.7973 - acc: 0.7878 - val_loss: 0.8512 - val_acc: 0.7492
# Epoch 25/50
# 40/40 [==============================] - 39s 965ms/step - loss: 0.7689 - acc: 0.7929 - val_loss: 0.8819 - val_acc: 0.7460
# Epoch 26/50
# 40/40 [==============================] - 39s 965ms/step - loss: 0.7897 - acc: 0.7769 - val_loss: 0.8300 - val_acc: 0.7556
# Epoch 27/50
# 40/40 [==============================] - 38s 957ms/step - loss: 0.7648 - acc: 0.7902 - val_loss: 0.8113 - val_acc: 0.7683
# Epoch 28/50
# 40/40 [==============================] - 39s 974ms/step - loss: 0.7515 - acc: 0.7874 - val_loss: 0.8672 - val_acc: 0.7206
# Epoch 29/50
# 40/40 [==============================] - 39s 987ms/step - loss: 0.6742 - acc: 0.8091 - val_loss: 0.8290 - val_acc: 0.7397
# Epoch 30/50
# 40/40 [==============================] - 38s 949ms/step - loss: 0.7031 - acc: 0.8042 - val_loss: 0.8203 - val_acc: 0.7349
# Epoch 31/50
# 40/40 [==============================] - 39s 976ms/step - loss: 0.7254 - acc: 0.7841 - val_loss: 0.8418 - val_acc: 0.7206
# Epoch 32/50
# 40/40 [==============================] - 42s 1s/step - loss: 0.7139 - acc: 0.7862 - val_loss: 0.7538 - val_acc: 0.7873
# Epoch 33/50
# 40/40 [==============================] - 40s 990ms/step - loss: 0.6864 - acc: 0.8036 - val_loss: 0.7369 - val_acc: 0.7603
# Epoch 34/50
# 40/40 [==============================] - 40s 1s/step - loss: 0.7198 - acc: 0.7964 - val_loss: 0.8569 - val_acc: 0.7190
# Epoch 35/50
# 40/40 [==============================] - 41s 1s/step - loss: 0.6613 - acc: 0.8152 - val_loss: 0.7776 - val_acc: 0.7571
# Epoch 36/50
# 40/40 [==============================] - 41s 1s/step - loss: 0.6612 - acc: 0.8118 - val_loss: 0.8392 - val_acc: 0.7333
# Epoch 37/50
# 40/40 [==============================] - 41s 1s/step - loss: 0.6168 - acc: 0.8234 - val_loss: 0.8288 - val_acc: 0.7603
# Epoch 38/50
# 40/40 [==============================] - 41s 1s/step - loss: 0.6425 - acc: 0.8179 - val_loss: 0.7905 - val_acc: 0.7540
# Epoch 39/50
# 40/40 [==============================] - 42s 1s/step - loss: 0.6422 - acc: 0.8142 - val_loss: 0.7927 - val_acc: 0.7333
# Epoch 40/50
# 40/40 [==============================] - 43s 1s/step - loss: 0.6484 - acc: 0.8214 - val_loss: 0.7416 - val_acc: 0.7698
# Epoch 41/50
# 40/40 [==============================] - 41s 1s/step - loss: 0.6291 - acc: 0.8318 - val_loss: 0.7559 - val_acc: 0.7651
# Epoch 42/50
# 40/40 [==============================] - 42s 1s/step - loss: 0.5462 - acc: 0.8488 - val_loss: 0.7601 - val_acc: 0.7587
# Epoch 43/50
# 40/40 [==============================] - 43s 1s/step - loss: 0.5764 - acc: 0.8241 - val_loss: 0.7420 - val_acc: 0.7698
# Epoch 44/50
# 40/40 [==============================] - 42s 1s/step - loss: 0.5524 - acc: 0.8548 - val_loss: 0.8457 - val_acc: 0.7365
# Epoch 45/50
# 40/40 [==============================] - 43s 1s/step - loss: 0.5619 - acc: 0.8408 - val_loss: 0.8064 - val_acc: 0.7397
# Epoch 46/50
# 40/40 [==============================] - 43s 1s/step - loss: 0.5261 - acc: 0.8595 - val_loss: 0.7051 - val_acc: 0.7810
# Epoch 47/50
# 40/40 [==============================] - 45s 1s/step - loss: 0.5446 - acc: 0.8509 - val_loss: 0.7840 - val_acc: 0.7492
# Epoch 48/50
# 40/40 [==============================] - 45s 1s/step - loss: 0.5486 - acc: 0.8427 - val_loss: 0.7094 - val_acc: 0.7825
# Epoch 49/50
# 40/40 [==============================] - 45s 1s/step - loss: 0.4634 - acc: 0.8753 - val_loss: 0.6788 - val_acc: 0.7825
# Epoch 50/50
# 40/40 [==============================] - 45s 1s/step - loss: 0.4789 - acc: 0.8693 - val_loss: 0.6814 - val_acc: 0.7889
# Cuvanje tezina
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])

# %%
print_layers()
# Out:
# input_1
# trainable: False
# input_shape: (None, 32, 32, 3)
# output_shape: (None, 32, 32, 3)
# _____________
# zero_padding2d_1
# trainable: True
# input_shape: (None, 32, 32, 3)
# output_shape: (None, 38, 38, 3)
# _____________
# conv1/conv
# trainable: True
# input_shape: (None, 38, 38, 3)
# output_shape: (None, 16, 16, 64)
# _____________
# conv1/bn
# trainable: True
# input_shape: (None, 16, 16, 64)
# output_shape: (None, 16, 16, 64)
# _____________
# conv1/relu
# trainable: True
# input_shape: (None, 16, 16, 64)
# output_shape: (None, 16, 16, 64)
# _____________
# zero_padding2d_2
# trainable: True
# input_shape: (None, 16, 16, 64)
# output_shape: (None, 18, 18, 64)
# _____________
# pool1
# trainable: True
# input_shape: (None, 18, 18, 64)
# output_shape: (None, 8, 8, 64)
# _____________
# conv2_block1_0_bn
# trainable: True
# input_shape: (None, 8, 8, 64)
# output_shape: (None, 8, 8, 64)
# _____________
# conv2_block1_0_relu
# trainable: True
# input_shape: (None, 8, 8, 64)
# output_shape: (None, 8, 8, 64)
# _____________
# conv2_block1_1_conv
# trainable: True
# input_shape: (None, 8, 8, 64)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block1_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block1_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block1_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block1_concat
# trainable: True
# input_shape: [(None, 8, 8, 64), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 96)
# _____________
# conv2_block2_0_bn
# trainable: True
# input_shape: (None, 8, 8, 96)
# output_shape: (None, 8, 8, 96)
# _____________
# conv2_block2_0_relu
# trainable: True
# input_shape: (None, 8, 8, 96)
# output_shape: (None, 8, 8, 96)
# _____________
# conv2_block2_1_conv
# trainable: True
# input_shape: (None, 8, 8, 96)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block2_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block2_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block2_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block2_concat
# trainable: True
# input_shape: [(None, 8, 8, 96), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_0_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_0_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_1_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block3_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block3_concat
# trainable: True
# input_shape: [(None, 8, 8, 128), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 160)
# _____________
# conv2_block4_0_bn
# trainable: True
# input_shape: (None, 8, 8, 160)
# output_shape: (None, 8, 8, 160)
# _____________
# conv2_block4_0_relu
# trainable: True
# input_shape: (None, 8, 8, 160)
# output_shape: (None, 8, 8, 160)
# _____________
# conv2_block4_1_conv
# trainable: True
# input_shape: (None, 8, 8, 160)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block4_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block4_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block4_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block4_concat
# trainable: True
# input_shape: [(None, 8, 8, 160), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 192)
# _____________
# conv2_block5_0_bn
# trainable: True
# input_shape: (None, 8, 8, 192)
# output_shape: (None, 8, 8, 192)
# _____________
# conv2_block5_0_relu
# trainable: True
# input_shape: (None, 8, 8, 192)
# output_shape: (None, 8, 8, 192)
# _____________
# conv2_block5_1_conv
# trainable: True
# input_shape: (None, 8, 8, 192)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block5_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block5_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block5_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block5_concat
# trainable: True
# input_shape: [(None, 8, 8, 192), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 224)
# _____________
# conv2_block6_0_bn
# trainable: True
# input_shape: (None, 8, 8, 224)
# output_shape: (None, 8, 8, 224)
# _____________
# conv2_block6_0_relu
# trainable: True
# input_shape: (None, 8, 8, 224)
# output_shape: (None, 8, 8, 224)
# _____________
# conv2_block6_1_conv
# trainable: True
# input_shape: (None, 8, 8, 224)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block6_1_bn
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block6_1_relu
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 128)
# _____________
# conv2_block6_2_conv
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 8, 8, 32)
# _____________
# conv2_block6_concat
# trainable: True
# input_shape: [(None, 8, 8, 224), (None, 8, 8, 32)]
# output_shape: (None, 8, 8, 256)
# _____________
# pool2_bn
# trainable: True
# input_shape: (None, 8, 8, 256)
# output_shape: (None, 8, 8, 256)
# _____________
# pool2_relu
# trainable: True
# input_shape: (None, 8, 8, 256)
# output_shape: (None, 8, 8, 256)
# _____________
# pool2_conv
# trainable: True
# input_shape: (None, 8, 8, 256)
# output_shape: (None, 8, 8, 128)
# _____________
# pool2_pool
# trainable: True
# input_shape: (None, 8, 8, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_0_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_0_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_1_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block1_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block1_concat
# trainable: True
# input_shape: [(None, 4, 4, 128), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 160)
# _____________
# conv3_block2_0_bn
# trainable: True
# input_shape: (None, 4, 4, 160)
# output_shape: (None, 4, 4, 160)
# _____________
# conv3_block2_0_relu
# trainable: True
# input_shape: (None, 4, 4, 160)
# output_shape: (None, 4, 4, 160)
# _____________
# conv3_block2_1_conv
# trainable: True
# input_shape: (None, 4, 4, 160)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block2_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block2_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block2_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block2_concat
# trainable: True
# input_shape: [(None, 4, 4, 160), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 192)
# _____________
# conv3_block3_0_bn
# trainable: True
# input_shape: (None, 4, 4, 192)
# output_shape: (None, 4, 4, 192)
# _____________
# conv3_block3_0_relu
# trainable: True
# input_shape: (None, 4, 4, 192)
# output_shape: (None, 4, 4, 192)
# _____________
# conv3_block3_1_conv
# trainable: True
# input_shape: (None, 4, 4, 192)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block3_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block3_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block3_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block3_concat
# trainable: True
# input_shape: [(None, 4, 4, 192), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 224)
# _____________
# conv3_block4_0_bn
# trainable: True
# input_shape: (None, 4, 4, 224)
# output_shape: (None, 4, 4, 224)
# _____________
# conv3_block4_0_relu
# trainable: True
# input_shape: (None, 4, 4, 224)
# output_shape: (None, 4, 4, 224)
# _____________
# conv3_block4_1_conv
# trainable: True
# input_shape: (None, 4, 4, 224)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block4_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block4_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block4_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block4_concat
# trainable: True
# input_shape: [(None, 4, 4, 224), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 256)
# _____________
# conv3_block5_0_bn
# trainable: True
# input_shape: (None, 4, 4, 256)
# output_shape: (None, 4, 4, 256)
# _____________
# conv3_block5_0_relu
# trainable: True
# input_shape: (None, 4, 4, 256)
# output_shape: (None, 4, 4, 256)
# _____________
# conv3_block5_1_conv
# trainable: True
# input_shape: (None, 4, 4, 256)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block5_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block5_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block5_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block5_concat
# trainable: True
# input_shape: [(None, 4, 4, 256), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 288)
# _____________
# conv3_block6_0_bn
# trainable: True
# input_shape: (None, 4, 4, 288)
# output_shape: (None, 4, 4, 288)
# _____________
# conv3_block6_0_relu
# trainable: True
# input_shape: (None, 4, 4, 288)
# output_shape: (None, 4, 4, 288)
# _____________
# conv3_block6_1_conv
# trainable: True
# input_shape: (None, 4, 4, 288)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block6_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block6_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block6_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block6_concat
# trainable: True
# input_shape: [(None, 4, 4, 288), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 320)
# _____________
# conv3_block7_0_bn
# trainable: True
# input_shape: (None, 4, 4, 320)
# output_shape: (None, 4, 4, 320)
# _____________
# conv3_block7_0_relu
# trainable: True
# input_shape: (None, 4, 4, 320)
# output_shape: (None, 4, 4, 320)
# _____________
# conv3_block7_1_conv
# trainable: True
# input_shape: (None, 4, 4, 320)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block7_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block7_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block7_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block7_concat
# trainable: True
# input_shape: [(None, 4, 4, 320), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 352)
# _____________
# conv3_block8_0_bn
# trainable: True
# input_shape: (None, 4, 4, 352)
# output_shape: (None, 4, 4, 352)
# _____________
# conv3_block8_0_relu
# trainable: True
# input_shape: (None, 4, 4, 352)
# output_shape: (None, 4, 4, 352)
# _____________
# conv3_block8_1_conv
# trainable: True
# input_shape: (None, 4, 4, 352)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block8_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block8_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block8_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block8_concat
# trainable: True
# input_shape: [(None, 4, 4, 352), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 384)
# _____________
# conv3_block9_0_bn
# trainable: True
# input_shape: (None, 4, 4, 384)
# output_shape: (None, 4, 4, 384)
# _____________
# conv3_block9_0_relu
# trainable: True
# input_shape: (None, 4, 4, 384)
# output_shape: (None, 4, 4, 384)
# _____________
# conv3_block9_1_conv
# trainable: True
# input_shape: (None, 4, 4, 384)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block9_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block9_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block9_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block9_concat
# trainable: True
# input_shape: [(None, 4, 4, 384), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 416)
# _____________
# conv3_block10_0_bn
# trainable: True
# input_shape: (None, 4, 4, 416)
# output_shape: (None, 4, 4, 416)
# _____________
# conv3_block10_0_relu
# trainable: True
# input_shape: (None, 4, 4, 416)
# output_shape: (None, 4, 4, 416)
# _____________
# conv3_block10_1_conv
# trainable: True
# input_shape: (None, 4, 4, 416)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block10_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block10_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block10_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block10_concat
# trainable: True
# input_shape: [(None, 4, 4, 416), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 448)
# _____________
# conv3_block11_0_bn
# trainable: True
# input_shape: (None, 4, 4, 448)
# output_shape: (None, 4, 4, 448)
# _____________
# conv3_block11_0_relu
# trainable: True
# input_shape: (None, 4, 4, 448)
# output_shape: (None, 4, 4, 448)
# _____________
# conv3_block11_1_conv
# trainable: True
# input_shape: (None, 4, 4, 448)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block11_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block11_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block11_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block11_concat
# trainable: True
# input_shape: [(None, 4, 4, 448), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 480)
# _____________
# conv3_block12_0_bn
# trainable: True
# input_shape: (None, 4, 4, 480)
# output_shape: (None, 4, 4, 480)
# _____________
# conv3_block12_0_relu
# trainable: True
# input_shape: (None, 4, 4, 480)
# output_shape: (None, 4, 4, 480)
# _____________
# conv3_block12_1_conv
# trainable: True
# input_shape: (None, 4, 4, 480)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block12_1_bn
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block12_1_relu
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 128)
# _____________
# conv3_block12_2_conv
# trainable: True
# input_shape: (None, 4, 4, 128)
# output_shape: (None, 4, 4, 32)
# _____________
# conv3_block12_concat
# trainable: True
# input_shape: [(None, 4, 4, 480), (None, 4, 4, 32)]
# output_shape: (None, 4, 4, 512)
# _____________
# pool3_bn
# trainable: True
# input_shape: (None, 4, 4, 512)
# output_shape: (None, 4, 4, 512)
# _____________
# pool3_relu
# trainable: True
# input_shape: (None, 4, 4, 512)
# output_shape: (None, 4, 4, 512)
# _____________
# pool3_conv
# trainable: True
# input_shape: (None, 4, 4, 512)
# output_shape: (None, 4, 4, 256)
# _____________
# pool3_pool
# trainable: True
# input_shape: (None, 4, 4, 256)
# output_shape: (None, 2, 2, 256)
# _____________
# conv4_block1_0_bn
# trainable: True
# input_shape: (None, 2, 2, 256)
# output_shape: (None, 2, 2, 256)
# _____________
# conv4_block1_0_relu
# trainable: True
# input_shape: (None, 2, 2, 256)
# output_shape: (None, 2, 2, 256)
# _____________
# conv4_block1_1_conv
# trainable: True
# input_shape: (None, 2, 2, 256)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block1_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block1_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block1_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block1_concat
# trainable: True
# input_shape: [(None, 2, 2, 256), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 288)
# _____________
# conv4_block2_0_bn
# trainable: True
# input_shape: (None, 2, 2, 288)
# output_shape: (None, 2, 2, 288)
# _____________
# conv4_block2_0_relu
# trainable: True
# input_shape: (None, 2, 2, 288)
# output_shape: (None, 2, 2, 288)
# _____________
# conv4_block2_1_conv
# trainable: True
# input_shape: (None, 2, 2, 288)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block2_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block2_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block2_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block2_concat
# trainable: True
# input_shape: [(None, 2, 2, 288), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 320)
# _____________
# conv4_block3_0_bn
# trainable: True
# input_shape: (None, 2, 2, 320)
# output_shape: (None, 2, 2, 320)
# _____________
# conv4_block3_0_relu
# trainable: True
# input_shape: (None, 2, 2, 320)
# output_shape: (None, 2, 2, 320)
# _____________
# conv4_block3_1_conv
# trainable: True
# input_shape: (None, 2, 2, 320)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block3_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block3_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block3_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block3_concat
# trainable: True
# input_shape: [(None, 2, 2, 320), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 352)
# _____________
# conv4_block4_0_bn
# trainable: True
# input_shape: (None, 2, 2, 352)
# output_shape: (None, 2, 2, 352)
# _____________
# conv4_block4_0_relu
# trainable: True
# input_shape: (None, 2, 2, 352)
# output_shape: (None, 2, 2, 352)
# _____________
# conv4_block4_1_conv
# trainable: True
# input_shape: (None, 2, 2, 352)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block4_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block4_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block4_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block4_concat
# trainable: True
# input_shape: [(None, 2, 2, 352), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 384)
# _____________
# conv4_block5_0_bn
# trainable: True
# input_shape: (None, 2, 2, 384)
# output_shape: (None, 2, 2, 384)
# _____________
# conv4_block5_0_relu
# trainable: True
# input_shape: (None, 2, 2, 384)
# output_shape: (None, 2, 2, 384)
# _____________
# conv4_block5_1_conv
# trainable: True
# input_shape: (None, 2, 2, 384)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block5_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block5_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block5_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block5_concat
# trainable: True
# input_shape: [(None, 2, 2, 384), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 416)
# _____________
# conv4_block6_0_bn
# trainable: True
# input_shape: (None, 2, 2, 416)
# output_shape: (None, 2, 2, 416)
# _____________
# conv4_block6_0_relu
# trainable: True
# input_shape: (None, 2, 2, 416)
# output_shape: (None, 2, 2, 416)
# _____________
# conv4_block6_1_conv
# trainable: True
# input_shape: (None, 2, 2, 416)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block6_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block6_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block6_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block6_concat
# trainable: True
# input_shape: [(None, 2, 2, 416), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 448)
# _____________
# conv4_block7_0_bn
# trainable: True
# input_shape: (None, 2, 2, 448)
# output_shape: (None, 2, 2, 448)
# _____________
# conv4_block7_0_relu
# trainable: True
# input_shape: (None, 2, 2, 448)
# output_shape: (None, 2, 2, 448)
# _____________
# conv4_block7_1_conv
# trainable: True
# input_shape: (None, 2, 2, 448)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block7_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block7_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block7_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block7_concat
# trainable: True
# input_shape: [(None, 2, 2, 448), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 480)
# _____________
# conv4_block8_0_bn
# trainable: True
# input_shape: (None, 2, 2, 480)
# output_shape: (None, 2, 2, 480)
# _____________
# conv4_block8_0_relu
# trainable: True
# input_shape: (None, 2, 2, 480)
# output_shape: (None, 2, 2, 480)
# _____________
# conv4_block8_1_conv
# trainable: True
# input_shape: (None, 2, 2, 480)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block8_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block8_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block8_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block8_concat
# trainable: True
# input_shape: [(None, 2, 2, 480), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 512)
# _____________
# conv4_block9_0_bn
# trainable: True
# input_shape: (None, 2, 2, 512)
# output_shape: (None, 2, 2, 512)
# _____________
# conv4_block9_0_relu
# trainable: True
# input_shape: (None, 2, 2, 512)
# output_shape: (None, 2, 2, 512)
# _____________
# conv4_block9_1_conv
# trainable: True
# input_shape: (None, 2, 2, 512)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block9_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block9_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block9_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block9_concat
# trainable: True
# input_shape: [(None, 2, 2, 512), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 544)
# _____________
# conv4_block10_0_bn
# trainable: True
# input_shape: (None, 2, 2, 544)
# output_shape: (None, 2, 2, 544)
# _____________
# conv4_block10_0_relu
# trainable: True
# input_shape: (None, 2, 2, 544)
# output_shape: (None, 2, 2, 544)
# _____________
# conv4_block10_1_conv
# trainable: True
# input_shape: (None, 2, 2, 544)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block10_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block10_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block10_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block10_concat
# trainable: True
# input_shape: [(None, 2, 2, 544), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 576)
# _____________
# conv4_block11_0_bn
# trainable: True
# input_shape: (None, 2, 2, 576)
# output_shape: (None, 2, 2, 576)
# _____________
# conv4_block11_0_relu
# trainable: True
# input_shape: (None, 2, 2, 576)
# output_shape: (None, 2, 2, 576)
# _____________
# conv4_block11_1_conv
# trainable: True
# input_shape: (None, 2, 2, 576)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block11_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block11_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block11_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block11_concat
# trainable: True
# input_shape: [(None, 2, 2, 576), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 608)
# _____________
# conv4_block12_0_bn
# trainable: True
# input_shape: (None, 2, 2, 608)
# output_shape: (None, 2, 2, 608)
# _____________
# conv4_block12_0_relu
# trainable: True
# input_shape: (None, 2, 2, 608)
# output_shape: (None, 2, 2, 608)
# _____________
# conv4_block12_1_conv
# trainable: True
# input_shape: (None, 2, 2, 608)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block12_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block12_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block12_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block12_concat
# trainable: True
# input_shape: [(None, 2, 2, 608), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 640)
# _____________
# conv4_block13_0_bn
# trainable: True
# input_shape: (None, 2, 2, 640)
# output_shape: (None, 2, 2, 640)
# _____________
# conv4_block13_0_relu
# trainable: True
# input_shape: (None, 2, 2, 640)
# output_shape: (None, 2, 2, 640)
# _____________
# conv4_block13_1_conv
# trainable: True
# input_shape: (None, 2, 2, 640)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block13_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block13_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block13_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block13_concat
# trainable: True
# input_shape: [(None, 2, 2, 640), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 672)
# _____________
# conv4_block14_0_bn
# trainable: True
# input_shape: (None, 2, 2, 672)
# output_shape: (None, 2, 2, 672)
# _____________
# conv4_block14_0_relu
# trainable: True
# input_shape: (None, 2, 2, 672)
# output_shape: (None, 2, 2, 672)
# _____________
# conv4_block14_1_conv
# trainable: True
# input_shape: (None, 2, 2, 672)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block14_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block14_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block14_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block14_concat
# trainable: True
# input_shape: [(None, 2, 2, 672), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 704)
# _____________
# conv4_block15_0_bn
# trainable: True
# input_shape: (None, 2, 2, 704)
# output_shape: (None, 2, 2, 704)
# _____________
# conv4_block15_0_relu
# trainable: True
# input_shape: (None, 2, 2, 704)
# output_shape: (None, 2, 2, 704)
# _____________
# conv4_block15_1_conv
# trainable: True
# input_shape: (None, 2, 2, 704)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block15_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block15_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block15_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block15_concat
# trainable: True
# input_shape: [(None, 2, 2, 704), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 736)
# _____________
# conv4_block16_0_bn
# trainable: True
# input_shape: (None, 2, 2, 736)
# output_shape: (None, 2, 2, 736)
# _____________
# conv4_block16_0_relu
# trainable: True
# input_shape: (None, 2, 2, 736)
# output_shape: (None, 2, 2, 736)
# _____________
# conv4_block16_1_conv
# trainable: True
# input_shape: (None, 2, 2, 736)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block16_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block16_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block16_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block16_concat
# trainable: True
# input_shape: [(None, 2, 2, 736), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 768)
# _____________
# conv4_block17_0_bn
# trainable: True
# input_shape: (None, 2, 2, 768)
# output_shape: (None, 2, 2, 768)
# _____________
# conv4_block17_0_relu
# trainable: True
# input_shape: (None, 2, 2, 768)
# output_shape: (None, 2, 2, 768)
# _____________
# conv4_block17_1_conv
# trainable: True
# input_shape: (None, 2, 2, 768)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block17_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block17_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block17_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block17_concat
# trainable: True
# input_shape: [(None, 2, 2, 768), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 800)
# _____________
# conv4_block18_0_bn
# trainable: True
# input_shape: (None, 2, 2, 800)
# output_shape: (None, 2, 2, 800)
# _____________
# conv4_block18_0_relu
# trainable: True
# input_shape: (None, 2, 2, 800)
# output_shape: (None, 2, 2, 800)
# _____________
# conv4_block18_1_conv
# trainable: True
# input_shape: (None, 2, 2, 800)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block18_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block18_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block18_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block18_concat
# trainable: True
# input_shape: [(None, 2, 2, 800), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 832)
# _____________
# conv4_block19_0_bn
# trainable: True
# input_shape: (None, 2, 2, 832)
# output_shape: (None, 2, 2, 832)
# _____________
# conv4_block19_0_relu
# trainable: True
# input_shape: (None, 2, 2, 832)
# output_shape: (None, 2, 2, 832)
# _____________
# conv4_block19_1_conv
# trainable: True
# input_shape: (None, 2, 2, 832)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block19_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block19_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block19_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block19_concat
# trainable: True
# input_shape: [(None, 2, 2, 832), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 864)
# _____________
# conv4_block20_0_bn
# trainable: True
# input_shape: (None, 2, 2, 864)
# output_shape: (None, 2, 2, 864)
# _____________
# conv4_block20_0_relu
# trainable: True
# input_shape: (None, 2, 2, 864)
# output_shape: (None, 2, 2, 864)
# _____________
# conv4_block20_1_conv
# trainable: True
# input_shape: (None, 2, 2, 864)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block20_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block20_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block20_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block20_concat
# trainable: True
# input_shape: [(None, 2, 2, 864), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 896)
# _____________
# conv4_block21_0_bn
# trainable: True
# input_shape: (None, 2, 2, 896)
# output_shape: (None, 2, 2, 896)
# _____________
# conv4_block21_0_relu
# trainable: True
# input_shape: (None, 2, 2, 896)
# output_shape: (None, 2, 2, 896)
# _____________
# conv4_block21_1_conv
# trainable: True
# input_shape: (None, 2, 2, 896)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block21_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block21_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block21_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block21_concat
# trainable: True
# input_shape: [(None, 2, 2, 896), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 928)
# _____________
# conv4_block22_0_bn
# trainable: True
# input_shape: (None, 2, 2, 928)
# output_shape: (None, 2, 2, 928)
# _____________
# conv4_block22_0_relu
# trainable: True
# input_shape: (None, 2, 2, 928)
# output_shape: (None, 2, 2, 928)
# _____________
# conv4_block22_1_conv
# trainable: True
# input_shape: (None, 2, 2, 928)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block22_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block22_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block22_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block22_concat
# trainable: True
# input_shape: [(None, 2, 2, 928), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 960)
# _____________
# conv4_block23_0_bn
# trainable: True
# input_shape: (None, 2, 2, 960)
# output_shape: (None, 2, 2, 960)
# _____________
# conv4_block23_0_relu
# trainable: True
# input_shape: (None, 2, 2, 960)
# output_shape: (None, 2, 2, 960)
# _____________
# conv4_block23_1_conv
# trainable: True
# input_shape: (None, 2, 2, 960)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block23_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block23_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block23_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block23_concat
# trainable: True
# input_shape: [(None, 2, 2, 960), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 992)
# _____________
# conv4_block24_0_bn
# trainable: True
# input_shape: (None, 2, 2, 992)
# output_shape: (None, 2, 2, 992)
# _____________
# conv4_block24_0_relu
# trainable: True
# input_shape: (None, 2, 2, 992)
# output_shape: (None, 2, 2, 992)
# _____________
# conv4_block24_1_conv
# trainable: True
# input_shape: (None, 2, 2, 992)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block24_1_bn
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block24_1_relu
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 128)
# _____________
# conv4_block24_2_conv
# trainable: True
# input_shape: (None, 2, 2, 128)
# output_shape: (None, 2, 2, 32)
# _____________
# conv4_block24_concat
# trainable: True
# input_shape: [(None, 2, 2, 992), (None, 2, 2, 32)]
# output_shape: (None, 2, 2, 1024)
# _____________
# pool4_bn
# trainable: True
# input_shape: (None, 2, 2, 1024)
# output_shape: (None, 2, 2, 1024)
# _____________
# pool4_relu
# trainable: True
# input_shape: (None, 2, 2, 1024)
# output_shape: (None, 2, 2, 1024)
# _____________
# pool4_conv
# trainable: True
# input_shape: (None, 2, 2, 1024)
# output_shape: (None, 2, 2, 512)
# _____________
# pool4_pool
# trainable: True
# input_shape: (None, 2, 2, 512)
# output_shape: (None, 1, 1, 512)
# _____________
# conv5_block1_0_bn
# trainable: True
# input_shape: (None, 1, 1, 512)
# output_shape: (None, 1, 1, 512)
# _____________
# conv5_block1_0_relu
# trainable: True
# input_shape: (None, 1, 1, 512)
# output_shape: (None, 1, 1, 512)
# _____________
# conv5_block1_1_conv
# trainable: True
# input_shape: (None, 1, 1, 512)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block1_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block1_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block1_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block1_concat
# trainable: True
# input_shape: [(None, 1, 1, 512), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 544)
# _____________
# conv5_block2_0_bn
# trainable: True
# input_shape: (None, 1, 1, 544)
# output_shape: (None, 1, 1, 544)
# _____________
# conv5_block2_0_relu
# trainable: True
# input_shape: (None, 1, 1, 544)
# output_shape: (None, 1, 1, 544)
# _____________
# conv5_block2_1_conv
# trainable: True
# input_shape: (None, 1, 1, 544)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block2_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block2_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block2_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block2_concat
# trainable: True
# input_shape: [(None, 1, 1, 544), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 576)
# _____________
# conv5_block3_0_bn
# trainable: True
# input_shape: (None, 1, 1, 576)
# output_shape: (None, 1, 1, 576)
# _____________
# conv5_block3_0_relu
# trainable: True
# input_shape: (None, 1, 1, 576)
# output_shape: (None, 1, 1, 576)
# _____________
# conv5_block3_1_conv
# trainable: True
# input_shape: (None, 1, 1, 576)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block3_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block3_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block3_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block3_concat
# trainable: True
# input_shape: [(None, 1, 1, 576), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 608)
# _____________
# conv5_block4_0_bn
# trainable: True
# input_shape: (None, 1, 1, 608)
# output_shape: (None, 1, 1, 608)
# _____________
# conv5_block4_0_relu
# trainable: True
# input_shape: (None, 1, 1, 608)
# output_shape: (None, 1, 1, 608)
# _____________
# conv5_block4_1_conv
# trainable: True
# input_shape: (None, 1, 1, 608)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block4_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block4_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block4_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block4_concat
# trainable: True
# input_shape: [(None, 1, 1, 608), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 640)
# _____________
# conv5_block5_0_bn
# trainable: True
# input_shape: (None, 1, 1, 640)
# output_shape: (None, 1, 1, 640)
# _____________
# conv5_block5_0_relu
# trainable: True
# input_shape: (None, 1, 1, 640)
# output_shape: (None, 1, 1, 640)
# _____________
# conv5_block5_1_conv
# trainable: True
# input_shape: (None, 1, 1, 640)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block5_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block5_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block5_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block5_concat
# trainable: True
# input_shape: [(None, 1, 1, 640), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 672)
# _____________
# conv5_block6_0_bn
# trainable: True
# input_shape: (None, 1, 1, 672)
# output_shape: (None, 1, 1, 672)
# _____________
# conv5_block6_0_relu
# trainable: True
# input_shape: (None, 1, 1, 672)
# output_shape: (None, 1, 1, 672)
# _____________
# conv5_block6_1_conv
# trainable: True
# input_shape: (None, 1, 1, 672)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block6_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block6_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block6_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block6_concat
# trainable: True
# input_shape: [(None, 1, 1, 672), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 704)
# _____________
# conv5_block7_0_bn
# trainable: True
# input_shape: (None, 1, 1, 704)
# output_shape: (None, 1, 1, 704)
# _____________
# conv5_block7_0_relu
# trainable: True
# input_shape: (None, 1, 1, 704)
# output_shape: (None, 1, 1, 704)
# _____________
# conv5_block7_1_conv
# trainable: True
# input_shape: (None, 1, 1, 704)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block7_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block7_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block7_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block7_concat
# trainable: True
# input_shape: [(None, 1, 1, 704), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 736)
# _____________
# conv5_block8_0_bn
# trainable: True
# input_shape: (None, 1, 1, 736)
# output_shape: (None, 1, 1, 736)
# _____________
# conv5_block8_0_relu
# trainable: True
# input_shape: (None, 1, 1, 736)
# output_shape: (None, 1, 1, 736)
# _____________
# conv5_block8_1_conv
# trainable: True
# input_shape: (None, 1, 1, 736)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block8_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block8_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block8_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block8_concat
# trainable: True
# input_shape: [(None, 1, 1, 736), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 768)
# _____________
# conv5_block9_0_bn
# trainable: True
# input_shape: (None, 1, 1, 768)
# output_shape: (None, 1, 1, 768)
# _____________
# conv5_block9_0_relu
# trainable: True
# input_shape: (None, 1, 1, 768)
# output_shape: (None, 1, 1, 768)
# _____________
# conv5_block9_1_conv
# trainable: True
# input_shape: (None, 1, 1, 768)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block9_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block9_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block9_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block9_concat
# trainable: True
# input_shape: [(None, 1, 1, 768), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 800)
# _____________
# conv5_block10_0_bn
# trainable: True
# input_shape: (None, 1, 1, 800)
# output_shape: (None, 1, 1, 800)
# _____________
# conv5_block10_0_relu
# trainable: True
# input_shape: (None, 1, 1, 800)
# output_shape: (None, 1, 1, 800)
# _____________
# conv5_block10_1_conv
# trainable: True
# input_shape: (None, 1, 1, 800)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block10_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block10_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block10_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block10_concat
# trainable: True
# input_shape: [(None, 1, 1, 800), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 832)
# _____________
# conv5_block11_0_bn
# trainable: True
# input_shape: (None, 1, 1, 832)
# output_shape: (None, 1, 1, 832)
# _____________
# conv5_block11_0_relu
# trainable: True
# input_shape: (None, 1, 1, 832)
# output_shape: (None, 1, 1, 832)
# _____________
# conv5_block11_1_conv
# trainable: True
# input_shape: (None, 1, 1, 832)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block11_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block11_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block11_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block11_concat
# trainable: True
# input_shape: [(None, 1, 1, 832), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 864)
# _____________
# conv5_block12_0_bn
# trainable: True
# input_shape: (None, 1, 1, 864)
# output_shape: (None, 1, 1, 864)
# _____________
# conv5_block12_0_relu
# trainable: True
# input_shape: (None, 1, 1, 864)
# output_shape: (None, 1, 1, 864)
# _____________
# conv5_block12_1_conv
# trainable: True
# input_shape: (None, 1, 1, 864)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block12_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block12_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block12_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block12_concat
# trainable: True
# input_shape: [(None, 1, 1, 864), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 896)
# _____________
# conv5_block13_0_bn
# trainable: True
# input_shape: (None, 1, 1, 896)
# output_shape: (None, 1, 1, 896)
# _____________
# conv5_block13_0_relu
# trainable: True
# input_shape: (None, 1, 1, 896)
# output_shape: (None, 1, 1, 896)
# _____________
# conv5_block13_1_conv
# trainable: True
# input_shape: (None, 1, 1, 896)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block13_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block13_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block13_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block13_concat
# trainable: True
# input_shape: [(None, 1, 1, 896), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 928)
# _____________
# conv5_block14_0_bn
# trainable: True
# input_shape: (None, 1, 1, 928)
# output_shape: (None, 1, 1, 928)
# _____________
# conv5_block14_0_relu
# trainable: True
# input_shape: (None, 1, 1, 928)
# output_shape: (None, 1, 1, 928)
# _____________
# conv5_block14_1_conv
# trainable: True
# input_shape: (None, 1, 1, 928)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block14_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block14_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block14_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block14_concat
# trainable: True
# input_shape: [(None, 1, 1, 928), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 960)
# _____________
# conv5_block15_0_bn
# trainable: True
# input_shape: (None, 1, 1, 960)
# output_shape: (None, 1, 1, 960)
# _____________
# conv5_block15_0_relu
# trainable: True
# input_shape: (None, 1, 1, 960)
# output_shape: (None, 1, 1, 960)
# _____________
# conv5_block15_1_conv
# trainable: True
# input_shape: (None, 1, 1, 960)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block15_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block15_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block15_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block15_concat
# trainable: True
# input_shape: [(None, 1, 1, 960), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 992)
# _____________
# conv5_block16_0_bn
# trainable: True
# input_shape: (None, 1, 1, 992)
# output_shape: (None, 1, 1, 992)
# _____________
# conv5_block16_0_relu
# trainable: True
# input_shape: (None, 1, 1, 992)
# output_shape: (None, 1, 1, 992)
# _____________
# conv5_block16_1_conv
# trainable: True
# input_shape: (None, 1, 1, 992)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block16_1_bn
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block16_1_relu
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 128)
# _____________
# conv5_block16_2_conv
# trainable: True
# input_shape: (None, 1, 1, 128)
# output_shape: (None, 1, 1, 32)
# _____________
# conv5_block16_concat
# trainable: True
# input_shape: [(None, 1, 1, 992), (None, 1, 1, 32)]
# output_shape: (None, 1, 1, 1024)
# _____________
# bn
# trainable: True
# input_shape: (None, 1, 1, 1024)
# output_shape: (None, 1, 1, 1024)
# _____________
# relu
# trainable: True
# input_shape: (None, 1, 1, 1024)
# output_shape: (None, 1, 1, 1024)
# _____________
# max_pool
# trainable: True
# input_shape: (None, 1, 1, 1024)
# output_shape: (None, 1024)
# _____________
# dense_1
# trainable: True
# input_shape: (None, 1024)
# output_shape: (None, 16)
# _____________
# dropout_1
# trainable: True
# input_shape: (None, 16)
# output_shape: (None, 16)
# _____________
# batch_normalization_1
# trainable: True
# input_shape: (None, 16)
# output_shape: (None, 16)
# _____________
# dense_2
# trainable: True
# input_shape: (None, 16)
# output_shape: (None, 6)
# _____________

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sn
import pandas as pd
import tensorflow as tf

def print_classification_report():
    # Confution Matrix and Classification Report
    Y_pred = model.predict_generator(test_generator, len(test_generator))
    y_pred = np.argmax(Y_pred, axis=1)

    print('Classification Report')
    target_names = list(test_generator.class_indices.keys())
    print(classification_report(test_generator.classes, y_pred, target_names=target_names))
    
    print('Confusion Matrix')
    conf_mat = confusion_matrix(test_generator.classes, y_pred)
    df_cm = pd.DataFrame(conf_mat, index = target_names, columns = target_names)
    plt.figure(figsize = (10,7))
    sn.heatmap(df_cm, annot=True)
    
def save_model():
    print("sacuvavanje modela")
    
    keras_file = project_dir+"keras_model.h5"
    model.save(keras_file)
    converter = tf.lite.TFLiteConverter.from_keras_model_file(keras_file)
    tflite_model = converter.convert()
    converted_file = project_dir+"converted_model.tflite"
    open(converted_file, "wb").write(tflite_model)

    print("model je sacuvan.")

# %%
#load_weights()
print_classification_report()
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#    cardboard       0.13      0.12      0.12       101
#        glass       0.16      0.14      0.15       125
#        metal       0.17      0.20      0.18       102
#        paper       0.23      0.26      0.24       148
#      plastic       0.18      0.17      0.17       120
#        trash       0.12      0.09      0.10        34
#
#     accuracy                           0.18       630
#    macro avg       0.17      0.16      0.16       630
# weighted avg       0.17      0.18      0.18       630
#
# Confusion Matrix

# %%
save_model()
# Out:
# sacuvavanje modela
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\tensorflow_core\lite\python\util.py:249: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From C:\Users\aleks\Anaconda3\lib\site-packages\tensorflow_core\python\framework\graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 612 variables.
# INFO:tensorflow:Converted 612 variables to const ops.
# model je sacuvan.
